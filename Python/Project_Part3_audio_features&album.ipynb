# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
# Mai_Dang Client ID&Scecret
Client_ID = "333b1355d6044b42abcf1f7d65b71f4b"
Client_Secret="941f247793fa4560a45ed23bf371a579"

# %%
#Authentication 
client_credentials_manager = SpotifyClientCredentials(client_id=Client_ID, client_secret=Client_Secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
tracks = tracks = pd.read_csv('../Resources/Final_Completed/tracks.csv')
tracks
# Out:
#       index                Track_Id            Track_Name  Explicit  \
# 0         0  46IZ0fSY2mpAiktS3KOqds            Easy On Me     False
# 1         1  5HCyWlXZPP0y6Gqq8TgA20                  Stay      True
# 2         2  27NovPIUIRrOZoCHxABJwK         Industry Baby      True
# 3         3  58UKC45GPNTflCN6nwCUeF            Fancy Like     False
# 4         4  3rmo8F54jFF8OgYsqTxm5d            Bad Habits     False
# ...     ...                     ...                   ...       ...
# 7185   7185  051NZ3rr3HXTULCEySJRX3        Used To Love U     False
# 7186   7186  1NtMkOgf5U9YMaXyuEIRn2          Call My Name     False
# 7187   7187  6Pag4ElNe0Cfdn7kNmgzEH  Let's Get It Started     False
# 7188   7188  6NhpIdjYoufuNNlBsgOztc    Suds In The Bucket     False
# 7189   7189  5kKH5GGlL5fndKkFLN4NSf             Locked Up      True
#
#       Popularity  Is_local track_type
# 0             86     False      track
# 1             88     False      track
# ...

# %%
#Testing the API call 
song_id = "6MFQeWtk7kxWGydnJB2y36"

# Retrieve audio features
audio_features = sp.audio_features(song_id)

# Display the audio features
audio_features
# Out:
# [None]

# %%
#Define the values of the counter and max_count 
counter = 0 
max_count = 50

# %%
#Define the audio_feature_list and null value for the loop
audio_features_list = []
null_value = None

# %%
#These are the IDs that did not exist, I made a mistake at some point. These are not real track_id, 2 are single(album)Id and one is missing a letteror two. 
# track_list[2868] = '6JOeNbZ3X6dtXusG3hkHn8'
# track_list[1321]
#track_list[6914]
# Out:
# '6MFQeWtk7kxWGydnJB2y36'

# %%
# track_list = tracks['Track_Id'].unique().tolist()
# track_list
tracks['Track_Id'] = track_list

# %%
tracks['Track_Id'][2869]
# Out:
# '6Az2Ll2CPnWYQ2BgiHf4Di'

# %%
#The loop to get the audio_features 
while counter < len(track_list): 
    for track_id in track_list[counter: len(track_list)]:
        # Search for the track using the song and artist names
        results = sp.audio_features(track_id)
        # Extract the track and artist details
        if len(results) > 0:
            track = results[0]
            track_data = { "Track_Id" : track_id,
                          "Danceability" : track['danceability'],
                          "Energy": track['energy'],
                          "Audio_key" : track['key'], 
                          "Loudness": track['loudness'], 
                          "Mode":track['mode'], 
                          "Speechiness": track['speechiness'], 
                          "Acousticness": track['acousticness'], 
                          "Instrumentalness": track['instrumentalness'], 
                          "Liveness": track['liveness'], 
                          "Valence": track['valence'], 
                          "Tempo": track['tempo'], 
                          "Uri": track['uri'], 
                          "Track_herf": track['track_href'], 
                          "Duration_ms": track['duration_ms'], 
                          "Time_signature" : track['time_signature'] 
                            }
            audio_features_list.append(track_data)
        else:
            #If there is no audio_feature: 
            track_data = { "Track_Id" : track_id,
                          "Danceability" : null_value,
                          "Energy": null_value,
                          "Audio_key" : null_value, 
                          "Loudness": null_value, 
                          "Mode": null_value, 
                          "Speechiness": null_value, 
                          "Acousticness": null_value, 
                          "Instrumentalness": null_value, 
                          "Liveness": null_value, 
                          "Valence": null_value, 
                          "Tempo": null_value, 
                          "Uri": null_value, 
            
                          "Track_herf": null_value, 
                          "Duration_ms": null_value, 
                          "Time_signature" : null_value 
                            }
            audio_features_list.append(track_data)
        counter = counter+1
        print(f"Now printing{counter}")
    print (f"Successfully retrieve {counter} songs")
    print("---------------------------------------------")
# Out:
# Now printing7016
# Now printing7017
# Now printing7018
# Now printing7019
# Now printing7020
# Now printing7021
# Now printing7022
# Now printing7023
# Now printing7024
# Now printing7025
# Now printing7026
# Now printing7027
# Now printing7028
# Now printing7029
# Now printing7030
# Now printing7031
# Now printing7032
# Now printing7033
# Now printing7034
# Now printing7035
# Now printing7036
# Now printing7037
# Now printing7038
# Now printing7039
# Now printing7040
# Now printing7041
# Now printing7042
# Now printing7043
# Now printing7044
# Now printing7045
# Now printing7046
# Now printing7047
# Now printing7048
# Now printing7049
# Now printing7050
# Now printing7051
# Now printing7052
# Now printing7053
# Now printing7054
# Now printing7055
# Now printing7056
# Now printing7057
# Now printing7058
# Now printing7059
# Now printing7060
# Now printing7061
# Now printing7062
# Now printing7063
# Now printing7064
# Now printing7065
# Now printing7066
# Now printing7067
# ...

# %%
len(audio_features_list)
# Out:
# 7188

# %%
#make a dataframe from the audio_feature_list 
df = pd.DataFrame(audio_features_list)
df
# Out:
#                     Track_Id  Danceability  Energy  Audio_key  Loudness  Mode  \
# 0     46IZ0fSY2mpAiktS3KOqds         0.604   0.366          5    -7.519     1
# 1     5HCyWlXZPP0y6Gqq8TgA20         0.591   0.764          1    -5.484     1
# 2     27NovPIUIRrOZoCHxABJwK         0.736   0.704          3    -7.409     0
# 3     58UKC45GPNTflCN6nwCUeF         0.647   0.765          1    -6.459     1
# 4     3rmo8F54jFF8OgYsqTxm5d         0.807   0.893         11    -3.745     0
# ...                      ...           ...     ...        ...       ...   ...
# 7183  051NZ3rr3HXTULCEySJRX3         0.661   0.794          7    -4.776     1
# 7184  1NtMkOgf5U9YMaXyuEIRn2         0.622   0.574          5    -5.068     0
# 7185  6Pag4ElNe0Cfdn7kNmgzEH         0.850   0.477          2   -10.820     1
# 7186  6NhpIdjYoufuNNlBsgOztc         0.511   0.903         10    -3.163     1
# 7187  5kKH5GGlL5fndKkFLN4NSf         0.807   0.611          7    -6.264     1
#
# ...

# %%
#Drop dupliactes 
df.drop_duplicates()
df
# Out:
#                     Track_Id  Danceability  Energy  Audio_key  Loudness  Mode  \
# 0     46IZ0fSY2mpAiktS3KOqds         0.604   0.366          5    -7.519     1
# 1     5HCyWlXZPP0y6Gqq8TgA20         0.591   0.764          1    -5.484     1
# 2     27NovPIUIRrOZoCHxABJwK         0.736   0.704          3    -7.409     0
# 3     58UKC45GPNTflCN6nwCUeF         0.647   0.765          1    -6.459     1
# 4     3rmo8F54jFF8OgYsqTxm5d         0.807   0.893         11    -3.745     0
# ...                      ...           ...     ...        ...       ...   ...
# 7183  051NZ3rr3HXTULCEySJRX3         0.661   0.794          7    -4.776     1
# 7184  1NtMkOgf5U9YMaXyuEIRn2         0.622   0.574          5    -5.068     0
# 7185  6Pag4ElNe0Cfdn7kNmgzEH         0.850   0.477          2   -10.820     1
# 7186  6NhpIdjYoufuNNlBsgOztc         0.511   0.903         10    -3.163     1
# 7187  5kKH5GGlL5fndKkFLN4NSf         0.807   0.611          7    -6.264     1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7188 entries, 0 to 7187
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track_Id          7188 non-null   object
#  1   Danceability      7188 non-null   float64
#  2   Energy            7188 non-null   float64
#  3   Audio_key         7188 non-null   int64
#  4   Loudness          7188 non-null   float64
#  5   Mode              7188 non-null   int64
#  6   Speechiness       7188 non-null   float64
#  7   Acousticness      7188 non-null   float64
#  8   Instrumentalness  7188 non-null   float64
#  9   Liveness          7188 non-null   float64
#  10  Valence           7188 non-null   float64
#  11  Tempo             7188 non-null   float64
#  12  Uri               7188 non-null   object
#  13  Track_herf        7188 non-null   object
#  14  Duration_ms       7188 non-null   int64
#  15  Time_signature    7188 non-null   int64
# ...

# %%
df.to_csv("../Resources/Final_Completed/audio_features.csv")

# %%
#Testing 
# Specify the track ID
# track_id = '5kKH5GGlL5fndKkFLN4NSf'

# # Retrieve track information
# track_info = sp.track(track_id)

# # Extract the album ID and album information
# album_id = track_info['album']['id']
# album_info = track_info['album']

# # Display the album ID and album information
# print("Album ID:", album_id)
# album_info['album_type']
# album_info['href']
# album_info['id']
# album_info['name']
# album_info['release_date']
# album_info['release_date_precision']
# album_info['total_tracks']
# album_info['uri']

# %%
#Define values 
counter = 0 
max_count = 50 
album_info_list = []
album = []

# %%
# Loop to get the album_id only 
while counter < len(track_list): 
    for track_id in track_list[counter: len(track_list)]:
        # Retrieve track information
      album_info = sp.album(album_id)
        # Extract the album ID and album information
        album_info = track_info['album']
        # Extract the track and artist details
        if len(results) > 0:
            track = results[0]
            album_info_data = { "Track_Id" : track_id,
                               "Album_Id": album_info['id']
                              }
            album_info_list.append(album_info_data)

        else:
            album_info_data = { "Track_Id" : track_id,
                               "Album_Id": null_value
                              }
            album_info_list.append(album_info_data)
        counter = counter+1
        print(f"Now printing{counter}")
    print (f"Successfully retrieve {counter} songs")
    print("---------------------------------------------")
# Out:
# Now printing7096
# Now printing7097
# Now printing7098
# Now printing7099
# Now printing7100
# Now printing7101
# Now printing7102
# Now printing7103
# Now printing7104
# Now printing7105
# Now printing7106
# Now printing7107
# Now printing7108
# Now printing7109
# Now printing7110
# Now printing7111
# Now printing7112
# Now printing7113
# Now printing7114
# Now printing7115
# Now printing7116
# Now printing7117
# Now printing7118
# Now printing7119
# Now printing7120
# Now printing7121
# Now printing7122
# Now printing7123
# Now printing7124
# Now printing7125
# Now printing7126
# Now printing7127
# Now printing7128
# Now printing7129
# Now printing7130
# Now printing7131
# Now printing7132
# Now printing7133
# Now printing7134
# Now printing7135
# Now printing7136
# Now printing7137
# Now printing7138
# Now printing7139
# Now printing7140
# Now printing7141
# Now printing7142
# Now printing7143
# Now printing7144
# Now printing7145
# Now printing7146
# Now printing7147
# ...

# %%
counter= counter+1
counter
# Out:
# 7191

# %%
len(album)
# Out:
# 0

# %%
len(album_info_list)
# Out:
# 7189

# %%
#Makinalbum info table. This will be the relation table, the track_id and the album here are not unique as a song could be released in multiple album,
#and album could contain multiple songs 
album_info_df = pd.DataFrame(album_info_list)
album_info_df
# Out:
#                     Track_Id                Album_Id
# 0     46IZ0fSY2mpAiktS3KOqds  21jF5jlMtzo94wbxmJ18aa
# 1     5HCyWlXZPP0y6Gqq8TgA20  4QLAtpLNUsHEYrcHXmMIZZ
# 2     27NovPIUIRrOZoCHxABJwK  622NFw5Yk0OReMJ2XWcXUh
# 3     58UKC45GPNTflCN6nwCUeF  4sShdTo9jO2RGLgDkZBgN8
# 4     3rmo8F54jFF8OgYsqTxm5d  32iAEBstCjauDhyKpGjTuq
# ...                      ...                     ...
# 7184  051NZ3rr3HXTULCEySJRX3  4W6kVnBPgcW8zDYXbRHh2J
# 7185  1NtMkOgf5U9YMaXyuEIRn2  1jy9Nciz47PNHiUB7FxAjK
# 7186  6Pag4ElNe0Cfdn7kNmgzEH  0Yt6b5UlE4QbuD36dLqrTi
# 7187  6NhpIdjYoufuNNlBsgOztc  4Wx0gVzxrbRgxcaJ0M02Ik
# 7188  5kKH5GGlL5fndKkFLN4NSf  77eKpEVxmSr1RhqMlirlTF
#
# [7189 rows x 2 columns]

# %%
# #TEsting 
# album_id = '31tCg5RXhY5jpagfCPcQa2'
# album = sp.album(album_id)
# album['id']

# %%
#Getting only the album_id 
unique_album_ids = album_info_df['Album_Id'].unique().tolist()

# %%
len(unique_album_ids)
# Out:
# 3745

# %%
counter = 0
max_count= 50
album=[]

# %%
#Loop to get the album_info 
while counter < len(unique_album_ids): 
    for album_id in unique_album_ids[counter: len(unique_album_ids)]:
        # Retrieve track information
        album_info = sp.album(album_id)
        # Extract  album information
        if len(album_info) > 0:
            album_data = {
                "Album_Id": album_info['id'],
                "Album_Type": album_info['album_type'], 
                "Href": album_info['href'],
                "Album_Name": album_info['name'], 
                "Label": album_info['label'],
                "Release_date": album_info['release_date'],
                "Release_date_precision": album_info['release_date_precision'],
                "Total_tracks": album_info['total_tracks'], 
                "Uri": album_info['uri']}
            album.append(album_data)
        else:
            album_data = {
                "Album_Id": album_id,
                "Album_Type": null_value, 
                "Href": null_value,
                "Album_Name": null_value, 
                "Label": null_value,
                "Release_date": null_value,
                "Release_date_precision": null_value,
                "Total_tracks": null_value, 
                "Uri": null_value}
            album.append(album_data)
        counter = counter+1
        print(f"Now printing{counter}")
    print (f"Successfully retrieve {counter} albums")
    print("---------------------------------------------")
# Out:
# Now printing3715
# Now printing3716
# Now printing3717
# Now printing3718
# Now printing3719
# Now printing3720
# Now printing3721
# Now printing3722
# Now printing3723
# Now printing3724
# Now printing3725
# Now printing3726
# Now printing3727
# Now printing3728
# Now printing3729
# Now printing3730
# Now printing3731
# Now printing3732
# Now printing3733
# Now printing3734
# Now printing3735
# Now printing3736
# Now printing3737
# Now printing3738
# Now printing3739
# Now printing3740
# Now printing3741
# Now printing3742
# Now printing3743
# Now printing3744
# Now printing3745
# Successfully retrieve 3745 albums
# ---------------------------------------------

# %%
len(album)
# Out:
# 3745

# %%
#Makign album df 
album_df = pd.DataFrame(album)
album_df
# Out:
#                     Album_Id Album_Type  \
# 0     21jF5jlMtzo94wbxmJ18aa      album
# 1     4QLAtpLNUsHEYrcHXmMIZZ     single
# 2     622NFw5Yk0OReMJ2XWcXUh     single
# 3     4sShdTo9jO2RGLgDkZBgN8      album
# 4     32iAEBstCjauDhyKpGjTuq      album
# ...                      ...        ...
# 3740  3TPoenhq4aT0Yl3XNBbQ7X      album
# 3741  2CIOi72adKDDQpj9x69qpW      album
# 3742  1jy9Nciz47PNHiUB7FxAjK      album
# 3743  0Yt6b5UlE4QbuD36dLqrTi     single
# 3744  4Wx0gVzxrbRgxcaJ0M02Ik      album
#
#                                                    Href  \
# 0     https://api.spotify.com/v1/albums/21jF5jlMtzo9...
# 1     https://api.spotify.com/v1/albums/4QLAtpLNUsHE...
# 2     https://api.spotify.com/v1/albums/622NFw5Yk0OR...
# 3     https://api.spotify.com/v1/albums/4sShdTo9jO2R...
# 4     https://api.spotify.com/v1/albums/32iAEBstCjau...
# ...                                                 ...
# 3740  https://api.spotify.com/v1/albums/3TPoenhq4aT0...
# ...

# %%
#Save csv files 
album_info_df.to_csv("../Resources/Final_Completed/new_album_info.csv")
album_df.to_csv("../Resources/Final_Completed/album.csv")

# %%
album_df= album_df.drop_duplicates()
album_df
# Out:
#                     Album_Id Album_Type  \
# 0     21jF5jlMtzo94wbxmJ18aa      album
# 1     4QLAtpLNUsHEYrcHXmMIZZ     single
# 2     622NFw5Yk0OReMJ2XWcXUh     single
# 3     4sShdTo9jO2RGLgDkZBgN8      album
# 4     32iAEBstCjauDhyKpGjTuq      album
# ...                      ...        ...
# 3740  3TPoenhq4aT0Yl3XNBbQ7X      album
# 3741  2CIOi72adKDDQpj9x69qpW      album
# 3742  1jy9Nciz47PNHiUB7FxAjK      album
# 3743  0Yt6b5UlE4QbuD36dLqrTi     single
# 3744  4Wx0gVzxrbRgxcaJ0M02Ik      album
#
#                                                    Href  \
# 0     https://api.spotify.com/v1/albums/21jF5jlMtzo9...
# 1     https://api.spotify.com/v1/albums/4QLAtpLNUsHE...
# 2     https://api.spotify.com/v1/albums/622NFw5Yk0OR...
# 3     https://api.spotify.com/v1/albums/4sShdTo9jO2R...
# 4     https://api.spotify.com/v1/albums/32iAEBstCjau...
# ...                                                 ...
# 3740  https://api.spotify.com/v1/albums/3TPoenhq4aT0...
# ...

# %%
album_info_df = album_info_df.drop_duplicates()
album_info_df
# Out:
#                     Track_Id                Album_Id
# 0     46IZ0fSY2mpAiktS3KOqds  21jF5jlMtzo94wbxmJ18aa
# 1     5HCyWlXZPP0y6Gqq8TgA20  4QLAtpLNUsHEYrcHXmMIZZ
# 2     27NovPIUIRrOZoCHxABJwK  622NFw5Yk0OReMJ2XWcXUh
# 3     58UKC45GPNTflCN6nwCUeF  4sShdTo9jO2RGLgDkZBgN8
# 4     3rmo8F54jFF8OgYsqTxm5d  32iAEBstCjauDhyKpGjTuq
# ...                      ...                     ...
# 7184  051NZ3rr3HXTULCEySJRX3  4W6kVnBPgcW8zDYXbRHh2J
# 7185  1NtMkOgf5U9YMaXyuEIRn2  1jy9Nciz47PNHiUB7FxAjK
# 7186  6Pag4ElNe0Cfdn7kNmgzEH  0Yt6b5UlE4QbuD36dLqrTi
# 7187  6NhpIdjYoufuNNlBsgOztc  4Wx0gVzxrbRgxcaJ0M02Ik
# 7188  5kKH5GGlL5fndKkFLN4NSf  77eKpEVxmSr1RhqMlirlTF
#
# [7189 rows x 2 columns]

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3745 entries, 0 to 3744
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Album_Id                3745 non-null   object
#  1   Album_Type              3745 non-null   object
#  2   Href                    3745 non-null   object
#  3   Album_Name              3745 non-null   object
#  4   Label                   3745 non-null   object
#  5   Release_date            3745 non-null   object
#  6   Release_date_precision  3745 non-null   object
#  7   Total_tracks            3745 non-null   int64
#  8   Uri                     3745 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 292.6+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3745 entries, 0 to 3744
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Album_Id                3745 non-null   object
#  1   Album_Type              3745 non-null   object
#  2   Href                    3745 non-null   object
#  3   Album_Name              3745 non-null   object
#  4   Label                   3745 non-null   object
#  5   Release_date            3745 non-null   datetime64[ns]
#  6   Release_date_precision  3745 non-null   object
#  7   Total_tracks            3745 non-null   int64
#  8   Uri                     3745 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 292.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7188 entries, 0 to 7187
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track_Id          7188 non-null   object
#  1   Danceability      7188 non-null   float64
#  2   Energy            7188 non-null   float64
#  3   Audio_key         7188 non-null   int64
#  4   Loudness          7188 non-null   float64
#  5   Mode              7188 non-null   int64
#  6   Speechiness       7188 non-null   float64
#  7   Acousticness      7188 non-null   float64
#  8   Instrumentalness  7188 non-null   float64
#  9   Liveness          7188 non-null   float64
#  10  Valence           7188 non-null   float64
#  11  Tempo             7188 non-null   float64
#  12  Uri               7188 non-null   object
#  13  Track_herf        7188 non-null   object
#  14  Duration_ms       7188 non-null   int64
#  15  Time_signature    7188 non-null   int64
# ...
